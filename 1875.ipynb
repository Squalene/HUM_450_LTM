# %%
import pandas as pd
import os
import csv
from collections import Counter
DATA_DIR = 'data/'
POPULATION_DATA_DIR = DATA_DIR + 'population/'
PROCESSED_DATA_DIR = DATA_DIR + "processed/"

# %%
from ast import literal_eval


df_census_reduced = pd.read_csv(PROCESSED_DATA_DIR+'census_reduced.csv')
df_census_reduced[["chef_vocation", "enfants_profession", "pensionnaires_condition", "profession"]] = df_census_reduced[["chef_vocation", "enfants_profession", "pensionnaires_condition", "profession"]].applymap(literal_eval)
df_census_reduced
# Out:
#                   chef_vocation enfants_profession  \
# 0              [ve de framages]                 []
# 1                  [journalier]                 []
# 2                    [caregent]                 []
# 3       [gaciant trapre, louis]                 []
# 4                            []                 []
# ...                         ...                ...
# 378721                [rentier]                 []
# 378722             [journalier]                 []
# 378723                       []                 []
# 378724        [fomme de lestre]                 []
# 378725             [carrisseur]                 []
#
#                               pensionnaires_condition  annee  \
# 0                                                  []   1861
# 1                                  [commis negociant]   1861
# 2                                     [app cais negt]   1861
# 3       [pensionnaire, pensionnaire, domestique, ind]   1861
# 4                                      [id es, id es]   1861
# ...                                               ...    ...
# 378721                                             []   1858
# 378722                                             []   1858
# 378723                                             []   1858
# 378724                                             []   1858
# 378725                                             []   1858
#
#                                                profession
# 0                                        [ve de framages]
# 1                          [journalier, commis negociant]
# 2                               [caregent, app cais negt]
# 3       [gaciant trapre, louis, pensionnaire, pensionn...
# 4                                          [id es, id es]
# ...                                                   ...
# 378721                                          [rentier]
# 378722                                       [journalier]
# 378723                                                 []
# 378724                                  [fomme de lestre]
# 378725                                       [carrisseur]
#
# [378726 rows x 5 columns]

# %% [markdown]
# ## Reshape datastructure

# %%
df_job_year = df_census_reduced[["chef_vocation", "annee"]].explode("chef_vocation").copy()
df_job_year = df_job_year[~df_job_year["chef_vocation"].isin({"·", ""})]
df_job_year = df_job_year.dropna()
df_job_year
# Out:
#           chef_vocation  annee
# 0        ve de framages   1861
# 1            journalier   1861
# 2              caregent   1861
# 3        gaciant trapre   1861
# 3                 louis   1861
# ...                 ...    ...
# 378720       journalier   1858
# 378721          rentier   1858
# 378722       journalier   1858
# 378724  fomme de lestre   1858
# 378725       carrisseur   1858
#
# [368746 rows x 2 columns]

# %%
df_job_by_year = df_job_year.groupby("annee")["chef_vocation"].apply(list)
print("Jobs listed by year:")
df_job_by_year
# Out:
# Jobs listed by year:
# annee
# 1835    [rocureur, pintier, boulanger, voiturier, mare...
# 1836    [rocureur, pintier, journaliere, journaliere, ...
# 1837    [vocation, pintier, chapelier, macon, boulange...
# 1838    [racreur, boulanger, rintier, chapelier, journ...
# 1839    [chal, isaac, hte, fritz, marie, rose, louise,...
#                               ...
# 1894    [ronkere, antignaire, longere, rentier, hocola...
# 1895    [octave, blanche, sasa, elise, martha, louis, ...
# 1896    [louis, thilomine, anna, pieyse, helene, anna,...
# 1897    [rentiere, f mantiquane, lingere, serrurier, h...
# 1898    [marie virginie, marie arsule, annee de naissa...
# Name: chef_vocation, Length: 64, dtype: object

# %%
df_job_by_year[df_job_by_year.index == 1875]
# Out:
# annee
# 1875    [de meules, menagere, rentiere, rentier, gocia...
# Name: chef_vocation, dtype: object

# %%
top_per_year = 100
df_count_top_by_year = df_job_by_year.apply(lambda l: Counter(l).most_common(top_per_year))

df_top_job_by_year = df_count_top_by_year.apply(lambda l: [prof for prof, count in l])
print("Most frequent jobs by year:")
df_top_job_by_year
# Out:
# Most frequent jobs by year:
# annee
# 1835    [journalier, rentiere, proprietaire, vigneron,...
# 1836    [rentiere, proprietaire, journalier, journalie...
# 1837    [rentiere, vigneron, journalier, rentier, prop...
# 1838    [rentiere, journalier, rentier, vigneron, jour...
# 1839    [rentiere, rentier, vigneron, journalier, prop...
#                               ...
# 1894    [menagere, rentiere, journalier, agriculteur, ...
# 1895    [menagere, rentiere, agriculteur, couturiere, ...
# 1896    [menagere, rentiere, manoeuvre, agriculteur, g...
# 1897    [menagere, rentiere, agriculteur, manoeuvre, g...
# 1898    [menagere, rentiere, gociant, manoeuvre, agric...
# Name: chef_vocation, Length: 64, dtype: object

# %%
df_top_job_by_year[df_top_job_by_year.index == 1875].values
# Out:
# array([list(['rentiere', 'rentier', 'agriculteur', 'journalier', 'vocation', 'tailleur', 'journaliere', 'prietaire', 'gociant', 'proprietaire', 'negociant', 'jardinier', 'fermier', 'rnaliere', 'charpentier', 'couturiere', 'lingere', 'ouvrier', 'professeur', 'donnier', 'vigneron', 'jean', 'menuisier', 'felier', 'renuisier', 'pension', 'etier', 'dem', 'fetier', 'tilleur', 'marchande', 'atiere', 'menagere', 'gypsier', 'rnalier', 'macon', 'tailleuse', 'commis', 'manoeuvre', 'atier', 'ier', 'veuve', 'nuissier', 'tiere', 'etiere', 'julier', 'elieur', 'murier', 'pierre', 'vinagere', 'pration', 'piere', 'cordonnier', 'domestique', 'menoeuvre', 'angere', 'eon', 'julie', 'louisier', 'apsier', 'blantier', 'fesseur', 'turiere', 'cierge', 'tier', 'mation', 'pasteur', 'ouvriere', 'taire', 'psier', 'tonnier', 'jeon', 'ide', 'jules', 'instituteur', 'profession', 'peintre', 'tilleuse', 'tient pension', 'imprimeur', 'noeuvre', 'langer', 'guisier', 'huissier', 'ation', 'pation', 'noeure', 'ration', 'pintre', 'de police', 'employe', 'afetier', 'rodonnier', 'chauffeur', 'aiffeur', 'titutrice', 'relieur', 'pissier', 'marchand', 'fileur'])],
#       dtype=object)

# %%
total_occ = len(df_job_year)
print(f"After automatic correction we keep {total_occ} job occurrences.")

top_terms = set(df_top_job_by_year.explode())
print(f"There is {len(top_terms)} distinct terms in the {top_per_year} most frequent terms by year.")

total_kept_occ = sum(df_count_top_by_year.apply(lambda l: sum([count for prof, count in l])))
print(f"After keeping only occurrences of this {len(top_terms)} distinct terms, we have {total_kept_occ} job occurrences.")
print(f"This represent {total_kept_occ / total_occ * 100}% of the occurrences.")
# Out:
# After automatic correction we keep 368746 job occurrences.
# There is 566 distinct terms in the 100 most frequent terms by year.
# After keeping only occurrences of this 566 distinct terms, we have 232430 job occurrences.
# This represent 63.03254814967484% of the occurrences.

# %%
df_jobs_1855 = pd.read_excel(DATA_DIR+"metiers_1855.xlsx", index_col=0)
df_jobs_1855["prof_norm"] = df_jobs_1855["prof_norm"].apply(lambda x: x.replace("?", ""))
jobs_1855 = set(df_jobs_1855["prof_norm"])
print(f"There is {len(jobs_1855)} corrected jobs in 1885")
jobs_1855
# Out:
# There is 513 corrected jobs in 1885
# {"agent d'affaires",
#  'agent de change',
#  'agriculteur',
#  'agricultrice',
#  'antiquaire',
#  'apprenti',
#  'apprentie',
#  'architecte',
#  'archiviste',
#  'armurier',
#  'armurrier',
#  'arpenteur',
#  'artificier',
#  'artiste',
#  'artiste pedicure',
#  'asphalteur',
#  'assesseur',
#  'aubergiste',
#  'avec sa mere',
#  'aveugle',
#  'avocat',
#  'bandagiste',
#  'banquier',
#  'barbier',
#  'batelier',
#  'bedeau',
#  'belle-mere',
#  'bibliothecaire',
#  'bijoutier',
#  'biscomier',
#  'blanchisseuse',
#  'boitier',
#  'bordeuse',
#  'bottier',
#  'boucher',
#  'boulanger',
#  'boulangere',
#  'bourrelier',
#  'brasseur',
#  'brodeuse',
#  'brossier',
#  'bucheron',
#  'buraliste',
#  'cafetier',
#  'caissier',
#  'caissier des postes',
#  'capitaine de gendarmerie',
#  'carrier',
#  'carrossier',
#  'cartier',
#  'cartonnier',
#  'casernier',
#  'caviste',
#  'chamoiseur',
#  'chancelier',
#  'chapelain',
#  'chapelier',
#  'charbonnier',
#  'charcutier',
#  'charpentier',
#  'charpentiere',
#  'charretier',
#  'charron',
#  'chaudronnier',
#  'chauffeur',
#  "chef d'institut",
#  'chez m. renon',
#  'chiffonniere',
#  'chimiste',
#  'chocolatier',
#  'cigareuse',
#  'cocher',
#  'coiffeur',
#  'colonel',
#  'colporteur',
#  'commis',
#  'commis a la poste',
#  'commis ecrivain',
#  'commis negociant',
#  'commissaire',
#  'commissaire arpenteur',
#  'commissaire de police',
#  'commissaire des guerres',
#  'commissaire general',
#  'commission',
#  'commmissaire arpenteur',
#  'compositeur',
#  'comptable',
#  'concierge',
#  'concierge des casernes',
#  'conducteur',
#  'confiseur',
#  'confiseur patissier',
#  'confiseuse',
#  "conseiller d'etat",
#  'conservateur',
#  'constructeur',
#  'controleur a la poste',
#  'copiste',
#  'cordier',
#  'cordonnier',
#  'corroyeur',
#  'costille',
#  'coupeur de bois',
#  'courrier',
#  'courrier de famille',
#  'courtepointiere',
#  'courtier',
#  'coutelier',
#  'couturiere',
#  'couvreur',
#  'crieur public',
#  'crocheteur',
#  'cuisinier',
#  'cuisiniere',
#  'cure',
#  'daguerreotypiste',
#  'de chapeaux',
#  'de peine au chateau',
#  'de pension',
#  'de placement',
#  'degrossisseur',
#  'demoiselle de magasin',
#  'dentiste',
#  'des gendarmes',
#  'directeur',
#  "directeur de l'ecole normale",
#  "directeur de l'instruction publique",
#  'directeur de la fabrique',
#  'directeur des ecoles',
#  'directeur des pauvres',
#  'directeur des postes',
#  "directrice d'ecole",
#  'dmestique',
#  'domestique',
#  'domestique de',
#  'domestique et ouvrier',
#  "domestique garcon d'ecurie",
#  'domestique voiturier',
#  'donander',
#  'donneur de bains',
#  'doreur',
#  'douanier',
#  'dque',
#  'drapier',
#  'droguiste',
#  'ebeniste',
#  'ecrivain',
#  'ecrivain public',
#  'ecuyer',
#  'editeur',
#  'egayeur',
#  'emailleur',
#  'emouleur',
#  'empailleur',
#  'empailleur et logeur',
#  'employe',
#  'employe a la banque',
#  'employe au chateau',
#  'employe au penitencier',
#  'employe aux chemins de fer',
#  'employe postal',
#  'employe-chef',
#  'en batiment',
#  'en demeure',
#  'en pension',
#  'enfant naturel de louise',
#  'enterreur',
#  'entrepreneur',
#  'epicie',
#  'epicier',
#  'epicier etc.',
#  'equarisseur',
#  'eterneur',
#  'etudiant',
#  'fabircant de socques',
#  'fabricant',
#  "fabricant d'allumettes",
#  'fabricant de babouches',
#  'fabricant de bas',
#  'fabricant de casquettes',
#  'fabricant de chandelles',
#  'fabricant de chapeaux',
#  'fabricant de chapeaux de paille',
#  'fabricant de chauferettes',
#  'fabricant de chocolat',
#  'fabricant de cigares',
#  'fabricant de miroirs',
#  'fabricant de ouate',
#  'fabricant de papier peint',
#  'fabricant de parapluies',
#  'fabricant de poupees',
#  'fabricant de savon',
#  'facteur',
#  'facteur aux telegraphes',
#  "facteur d'instrument",
#  'facteur de lettres',
#  'facteur des sels',
#  'femme de chambre',
#  'femme de menage',
#  'ferblantier',
#  'fermier',
#  'fermiere',
#  'fileur',
#  'fileuse',
#  'fille de la veuve',
#  'fleuriste',
#  'fondeur',
#  'fontenier',
#  'fontenier et entrepreneur',
#  'forestier',
#  'fournier',
#  'fournisseur militaire',
#  'fripier',
#  'fripiere',
#  'fruitier',
#  'gagne-denier',
#  'gantier',
#  'gantiere',
#  "garcon d'ecurie",
#  'garcon de cafe',
#  'garcon de place',
#  'garcon voitur',
#  'garcon voiturier',
#  'garde champetre',
#  'garde de montbenon',
#  'garde fabrique',
#  'garde forestier',
#  'garde-malade',
#  'gendarme',
#  'giletiere',
#  'gouvernante',
#  'graveur',
#  'greffier',
#  'gypseur/gypsier',
#  'gypseur/gypsier et vernisseur',
#  'homme de menage',
#  'horloger',
#  'horlogere',
#  'huiller',
#  'huissier',
#  'huissier de police',
#  "huissier du conseil d'etat",
#  'huissier du prefet',
#  'huissier expert',
#  'id',
#  'imprimeur',
#  'imprimeur-libraire',
#  'incurable',
#  'infirmier',
#  'ingenieur',
#  'ingenieur en chemin de fer',
#  'inspecteur',
#  'inspecteur des boucheries',
#  'inspecteur des vignes',
#  'inspecteur forestier',
#  'inspecteur general des milices',
#  'institut',
#  'instituteur',
#  'instituteur et marchand',
#  'institutrice',
#  'instructeur',
#  'instructeur chef',
#  'instructeur de trompette',
#  'intendant du peage',
#  'jardinier',
#  'jardiniere',
#  'journalier',
#  'journaliere',
#  'juge',
#  'juge cantonal',
#  "juge d'appel",
#  'juge de paix',
#  'laitier',
#  'laitiere',
#  'lampiste',
#  'le mari employe',
#  "le mari employe a l'hospice",
#  'le mari portier',
#  'le mari tailleur',
#  'lessiveuse',
#  'libraire',
#  'limonadier',
#  'lingere',
#  'liquoriste',
#  'lithographe',
#  'locataire',
#  'loge',
#  'loge horloger id',
#  'logeuse',
#  'luthier',
#  'macon',
#  'macon et logeur',
#  'magasinier',
#  "maitre d'armes",
#  'maitre de gymnase',
#  'maitre de langue',
#  'maitre de musique',
#  'maitre de poste',
#  'maitre ramoneur',
#  'maitre valet',
#  "maitresse d'ecole",
#  'major des gendarmes',
#  'manœuvre',
#  'marbrier',
#  'marchand',
#  'marchand ambulant',
#  'marchand cantinier',
#  'marchand de bois',
#  'marchand de bric-a-brac',
#  'marchand de chevaux',
#  'marchand de chiens',
#  'marchand de chiffons',
#  'marchand de coton',
#  'marchand de fer',
#  'marchand de fer et quincaillerie',
#  'marchand de modes',
#  'marchand de musique',
#  'marchand de parapluies',
#  'marchand de toiles',
#  'marchand de verrerie',
#  'marchand de vins',
#  'marchand de volailles',
#  'marchand epicier',
#  'marchand papetier',
#  'marchand tailleur',
#  'marchand vitrier',
#  'marchande',
#  'marchande epiciere',
#  'marchande lingere',
#  'marechal',
#  'marechal-ferrant',
#  'marguiller',
#  'matelassier',
#  'mathematicien',
#  'mecanicien',
#  'medecin',
#  'megisseur',
#  'menagere',
#  'menuisier',
#  'menuisier et pintier',
#  'messager',
#  'meunier',
#  'meuniere',
#  'militaire',
#  'mineur',
#  'ministre',
#  'mme epice',
#  'modiste',
#  'monteur de boite',
#  'municipal',
#  'municipal et proprietaire',
#  'musee cantonal',
#  'musicien',
#  'musicienne',
#  'negociant',
#  'negociant et rentier',
#  'negt tanneur',
#  'notaire',
#  'notaire et boursier',
#  'notaire et municipal',
#  'nourrice',
#  'officier',
#  'opticien',
#  'orfevre',
#  'orthopediste',
#  'ouvrier',
#  'ouvrier au gaz',
#  'ouvrier aux chemins de fer',
#  'ouvrier boucher',
#  'ouvrier corroyeur',
#  'ouvrier de ville',
#  'ouvrier en papier peint',
#  'ouvrier fondeur',
#  'ouvrier gypseur',
#  'ouvrier macon au chemin de fer',
#  'ouvrier meunier',
#  'ouvrier papetier',
#  'ouvrier potier',
#  'ouvriere',
#  'ouvriere gantiere',
#  'pailleur de chaise',
#  'palefrenier',
#  'papetier',
#  'passementier',
#  'passementiere',
#  'pasteur',
#  'patissier',
#  'pecheur',
#  'peintre',
#  'pelletier',
#  'pensionnair',
#  'pensionnaire',
#  'pensionnaire mere',
#  'pensionnaires',
#  'perruquier',
#  'peseur',
#  'pharmacien',
#  'pianiste',
#  'pintier',
#  'pintier et logeur',
#  'pintiere',
#  'pionnier',
#  'piqueur',
#  'piquier',
#  'platrier',
#  'poelier',
#  'polisseur',
#  'porte-piano',
#  'portefaix',
#  'portier',
#  'potier',
#  "potier d'etain",
#  'prefet',
#  'prieur et logeur',
#  'procureur',
#  'procureur general',
#  'professeur',
#  'professeur de musique',
#  'proprietaire',
#  'proprietaire ',
#  'proprietaire et fabricant de chandelles',
#  'proprietaire et jardinier',
#  'proprietaire et negociant',
#  'proprietaire et rentier',
#  'ramoneur',
#  'receveur',
#  'receveur des peages',
#  'regent',
#  'regente',
#  'regisseur',
#  'regleur',
#  'relieur',
#  'relieur de seilles',
#  'relieur et pintier',
#  'remouleur',
#  'rentier',
#  'rentier-pensionnaire',
#  'rentiere',
#  'rentiere et tient pension',
#  'repasseuse',
#  'repasseuse et blanchisseuse',
#  'restaurateur',
#  'restaurateur et aubergiste',
#  's/vocation',
#  'sa fille naturelle',
#  'sa mere',
#  'sa niece',
#  'sa sœur',
#  'sabotier',
#  'sage-femme',
#  'sans vocation',
#  'sculpteur',
#  'secretaire',
#  'secretaire au chateau',
#  'secretaire au departement militaire',
#  'secretaire aux peages',
#  "secretaire de l'inspecteur des milices",
#  'secretaire du grand conseil',
#  'secretaire du juge de paix',
#  'secretaire municipal',
#  'sellier',
#  'sergent de gendarmerie',
#  'sergent de ville',
#  'sergent major de police',
#  'serrurier',
#  'socquier',
#  'sommelier',
#  'sommlier',
#  'sonneur',
#  'sous secretaire des ',
#  'stagiaire',
#  'substitut du procureur general',
#  'suppleant conducteur',
#  'syndic',
#  'taillandier',
#  'tailleur',
#  'tailleur de pierre',
#  'tailleur et logeur',
#  'tailleur journalier',
#  'tailleuse',
#  'tailleuse et logeuse',
#  'tanneur',
#  'tapissier',
#  'tapissiere',
#  'teinturier',
#  'teinturiere',
#  'telegraphiste',
#  'teneur de livre',
#  'tient pension',
#  'tient une ecole',
#  'tier',
#  'tier jardinier',
#  'timbreur',
#  'tisserand',
#  'tonnelier',
#  'tonnelier et pintier',
#  'tourneur',
#  'traiteur',
#  'treillisseur',
#  'tripier',
#  'tuilier',
#  'ulier',
#  'urneur',
#  'vannier',
#  'vendeur de vin',
#  'vernisseur',
#  'veterinaire',
#  'vigneron',
#  'visiteur des morts',
#  'vitrier',
#  'voiturier',
#  'voyer'}

# %%
terms_to_correct = top_terms - jobs_1855

print(f"After removing correct jobs, there is {len(terms_to_correct)} terms to check/correct")

with open('tocorrect.csv', 'w') as f:
    writer = csv.writer(f)
    for val in sorted(list(terms_to_correct)):
        writer.writerow([val])

print("Below are the terms, with their number of occurrence:")
occ_terms = df_job_year[df_job_year["profession"].isin(terms_to_correct)].groupby("profession").count()
occ_terms
# Out:
# After removing correct jobs, there is 385 terms to check/correct
# Below are the terms, with their number of occurrence:
#                  annee
# profession
# agent de police    438
# agricult            46
# agriculteur id      18
# agt                 18
# aide               557
# ...                ...
# vintier             65
# vocatier            20
# vocation          1727
# volontaire         264
# vve de chambre      52
#
# [385 rows x 1 columns]

# %%
occ_terms.sort_values("annee")[::-1]
# Out:
#             annee
# profession
# manoeuvre    8261
# gociant      5818
# pens         5402
# pensre       3695
# gypsier      3000
# ...           ...
# renlier         6
# merery          6
# echaud          5
# ailleuse        5
# ordonnier       5
#
# [385 rows x 1 columns]

# %%
to_correct_v1 = set(pd.read_csv(DATA_DIR+'tocorrect_v1.csv', sep=";", header = None)[0])
to_correct_v1
# Out:
# {'agent de police',
#  'agricult',
#  'agriculteur id',
#  'agt',
#  'aide',
#  'ailleuse',
#  'alire',
#  'alix',
#  'annee de naissance',
#  'annee de naissance .',
#  'ans',
#  'aopriculteur',
#  'app',
#  'app couturiere',
#  'app negociant',
#  'app tailleuse',
#  'apprentie modiste',
#  'apprentier',
#  'apprentis',
#  'apprentisse',
#  'arpentier',
#  'atier',
#  'atiere',
#  'atif',
#  'aypographe',
#  'bauquier',
#  'belmont',
#  'bem',
#  'ben',
#  'bens',
#  'berne',
#  'beulanger',
#  'bijoulier',
#  'bingere',
#  'blanchi ause',
#  'bonne',
#  'cafelier',
#  'caiffeur',
#  'catelier',
#  'chapellier',
#  'charon',
#  'charpent',
#  'charrelier',
#  'chirurgien',
#  'cimenteur',
#  'cinturier',
#  'clerc',
#  'cleve',
#  'clever caveug id',
#  'coge',
#  'commissionnaire',
#  'compagne',
#  'conne',
#  'conseiller',
#  'cord',
#  'cordonier',
#  'cordourier',
#  'coucher',
#  'cousiniere',
#  'couvrent',
#  'cullieateur',
#  'cullisateur',
#  'culottier',
#  'cultivateur',
#  'dam',
#  'de leur recepisse',
#  'de naisse',
#  'del',
#  'delle de magasin',
#  'dem',
#  'deux',
#  'dgne',
#  'dicelinaire',
#  'diciolinaire',
#  'diciphinaire id',
#  'diephinaire',
#  'dinier',
#  'docteur',
#  'dom',
#  'dome',
#  'domel',
#  'domest',
#  'domesti',
#  'domestiq',
#  'domestiqne',
#  'domestique .',
#  'domestique cleves oapheline',
#  'domestique domestique',
#  'domestique el regent',
#  'domestique id',
#  'domestique id id',
#  'domestique idem',
#  'domestique ouvrier',
#  'domestique pensionnaire',
#  'domestiques',
#  'domi',
#  'donnier',
#  'doue',
#  'dqe',
#  'dqu',
#  'dque dque',
#  'dque id',
#  'due',
#  'dve',
#  'e id',
#  'echaud',
#  'eleire',
#  'elene',
#  'elene aveug id',
#  'eleve',
#  'eleve engent',
#  'eleve regent',
#  'eleve regente',
#  'elieur',
#  'eline',
#  'emp',
#  'emp . a la gare',
#  'emp . au chateau',
#  'emp . postal',
#  'emp . so .',
#  'emp de banque',
#  'emp j p',
#  'emp j s',
#  'emp so',
#  'empl j s',
#  'empl postal',
#  'empley',
#  'employe s',
#  'employee',
#  'employer interne',
#  'en chambre',
#  'enf',
#  'enfant',
#  'enfant naturel',
#  'enft illegit',
#  'enpension',
#  'epalinges',
#  'epiciere',
#  'et',
#  'etier',
#  'etiere',
#  'etudiant in',
#  'etudiante',
#  'eypographe',
#  'fabriquent',
#  'fait des menages',
#  'felier',
#  'fem de ch',
#  'fem de chambre',
#  'femme de ch',
#  'fermiers',
#  'fernier',
#  'fetier',
#  'fille de boutique',
#  'fille de chambre',
#  'fille de magasin',
#  'filleuse',
#  'fortier',
#  'gagne denier',
#  'gailleur',
#  'garde de jour',
#  'garde feres',
#  'garde malade',
#  'garde police',
#  'gardinier',
#  'ge',
#  'gendanme',
#  'gere',
#  'gipier',
#  'gipseur',
#  'gipsier',
#  'gociant',
#  'gociante',
#  'gondarme',
#  'got',
#  'gotiant',
#  'gouvernant pensionnaire',
#  'gre',
#  'gte',
#  'guisier',
#  'gypseur',
#  'gypsier',
#  'henri',
#  'henuisier',
#  'hotelier',
#  'ici',
#  'id .',
#  'id a',
#  'id domestique',
#  'id dque',
#  'id i',
#  'id id',
#  'id id id',
#  'id id id id',
#  'id ls',
#  'id n',
#  'id ne aisse',
#  'id nee de naisse',
#  'id pensionnaire',
#  'ide',
#  'idem .',
#  'idem domestique',
#  'idemidem',
#  'ideon',
#  'idme',
#  'idod',
#  'idom',
#  'idt',
#  'ier',
#  'ilems',
#  'ineurable',
#  'infirme',
#  'istre',
#  'jann',
#  'jaque',
#  'jardinier domestique',
#  'jean',
#  'jenny',
#  'jeun',
#  'jeurn',
#  'jone',
#  'journ',
#  'journailler',
#  'journaillere',
#  'journaillier',
#  'journailliere',
#  'journal',
#  'journalie',
#  'journalierer',
#  'journallier',
#  'journalliere',
#  'juge d appel',
#  'julier',
#  'kem',
#  'la vigneron',
#  'labaure',
#  'laber',
#  'labour',
#  'laboureur',
#  'laboureure',
#  'laboureuse',
#  'langer',
#  'lans',
#  'laus',
#  'lausanne',
#  'lavandiere',
#  'lavendiere',
#  'lebaureur',
#  'lecheur',
#  'leffiveuse',
#  'lege',
#  'len eogemont',
#  'lessineuse',
#  'leur',
#  'leveregent idem',
#  'lie',
#  'lier',
#  'linger',
#  'logeur',
#  'louis',
#  'louise',
#  'loye',
#  'lque',
#  'ls vocation',
#  'lutry',
#  'm boucher',
#  'm cordonnier',
#  'm de pension',
#  'm jardinier',
#  'm tailleur',
#  'magon',
#  'maitre',
#  'maitresse',
#  'malade',
#  'manoeuvre',
#  'manouvrier',
#  'march',
#  'marchand de vin',
#  'marchde',
#  'marche',
#  'marchs',
#  'marichal',
#  'maron',
#  'masson',
#  'me de pension',
#  'menoeuvre',
#  'menrier',
#  'menrinier',
#  'menritier',
#  'mension',
#  'mere',
#  'merery',
#  'meron',
#  'minagere',
#  'monagere',
#  'monnier',
#  'moudon',
#  'municapal',
#  'munier',
#  'nalade',
#  'nalier',
#  nan,
#  'ne',
#  'nee de naisse',
#  'negt',
#  'ni ds',
#  'niculteur',
#  'nier',
#  'no de',
#  'no de leur recepisse',
#  'no des',
#  'noge',
#  'nsesonaire pensionnaire',
#  'nuissier',
#  'ordonnier',
#  'orferre',
#  'ounier',
#  'ournalier',
#  'ouv',
#  'ouv charpentier',
#  'ouv cordonnier',
#  'ouv de ville',
#  'ouv menuisier',
#  'ouv serrurier',
#  'ouvr macon d',
#  'ouvrier di',
#  'ouvrier loge',
#  'ouvrier menuisier',
#  'paint',
#  'pare',
#  'parent',
#  'paul',
#  'paus',
#  'peint',
#  'pelier',
#  'penre',
#  'pens',
#  'pens .',
#  'pens dque',
#  'pensi',
#  'pension',
#  'pension re',
#  'pensionaire',
#  'pensionaire idem',
#  'pensionn',
#  'pensionn .',
#  'pensionna',
#  'pensionnai',
#  'pensionnaire .',
#  'pensionnaire domestique',
#  'pensionnaire dque',
#  'pensionnaire id',
#  'pensionnaire id id',
#  'pensionnaire idem',
#  'pensionnaire pensionnaire',
#  'pensionnat',
#  'pensionne',
#  'pensionnre',
#  'pensionr',
#  'pensionre',
#  'pensre',
#  'pensre .',
#  'pensre de',
#  'pent',
#  'pentre',
#  'peus',
#  'pierre',
#  'pilleuse',
#  'pins',
#  'poins',
#  'point',
#  'poirt',
#  'pomese',
#  'poprietaire',
#  'potier de terre',
#  'pouit',
#  'pourcoucher',
#  'pout',
#  'prafesseur',
#  'pre',
#  'prietaire',
#  'print',
#  'profession',
#  'proprietair',
#  'psion',
#  'pully',
#  'rapes',
#  'reg',
#  'regis',
#  'regt',
#  'reguste',
#  'rent',
#  'rentiere .',
#  'rention',
#  'rentr',
#  'renuisier',
#  'reulier',
#  'revendeuse',
#  'rietaire',
#  'rintier',
#  'rnalier',
#  'rnaliere',
#  'rnsimie',
#  'ront',
#  'rontr',
#  'roprietaire',
#  's profession',
#  's vocation',
#  'sa fille',
#  'sage femme',
#  'sallieur',
#  'sans',
#  'sans profession',
#  'sans voc',
#  'sans vocat',
#  'sansetta',
#  'sansette',
#  'saus',
#  'scieur',
#  'seiller',
#  'seillier',
#  'serrurrier',
#  'servante',
#  'servante ouvrier',
#  'sifferand',
#  'sineraud',
#  'sommeiller',
#  'sommeliere',
#  'son domestique',
#  'spocation',
#  'spvocation',
#  'st',
#  'st cordonnier',
#  'st profess',
#  'st vocation',
#  'ste croix idhd',
#  'svocation',
#  'syvocation',
#  'taboureur',
#  'tailleur d habits',
#  'tailleur de pierres',
#  'tailleure',
#  'taillieur',
#  'taillieus',
#  'taillieuse',
#  'tanneux',
#  'tendeur de vin',
#  'terrassier',
#  'tient ecole',
#  'tiere',
#  'tilleur',
#  'tisseraud',
#  'toujours',
#  'typographe',
#  'une',
#  'valet de chambre',
#  'valteur',
#  'vandeur de vin',
#  'vend vin',
#  'vendoin',
#  'venre',
#  'veudeur de vin',
#  'veuve',
#  'vigneron d',
#  'vigneronne',
#  'vintier',
#  'vit de ses rentes',
#  'vit de sesrenter',
#  'vit de sesrentes',
#  'vocatier',
#  'vocation',
#  'voiturier .',
#  'volontaire',
#  'vve de chambre'}

# %% [markdown]
# # After manual cleaning

# %%
man_corr = pd.read_csv(DATA_DIR+'/corrected.csv')
man_corr
# Out:
#             original         corrected
# 0    agent de police   agent de police
# 1           agricult       agriculteur
# 2     agriculteur id  agriculteur|idem
# 3                agt             agent
# 4               aide              aide
# ..               ...               ...
# 472       volontaire        volontaire
# 473   vve de chambre  valet de chambre
# 474           murier          armurier
# 475       griculteur       agriculteur
# 476          renlier           rentier
#
# [477 rows x 2 columns]

# %%
correction_mapping = dict(zip(man_corr['original'], man_corr['corrected']))
correction_mapping
# Out:
# {'agent de police': 'agent de police',
#  'agricult': 'agriculteur',
#  'agriculteur id': 'agriculteur|idem',
#  'agt': 'agent',
#  'aide': 'aide',
#  'ailleuse': 'tailleuse',
#  'alire': 'NSP',
#  'alix': nan,
#  'annee de naissance': nan,
#  'annee de naissance .': nan,
#  'ans': 'NSP',
#  'aopriculteur': 'agriculteur',
#  'app': 'apprenti',
#  'app couturiere': 'apprentie couturiere',
#  'app negociant': 'apprenti negociant',
#  'app tailleuse': 'apprentie tailleuse',
#  'apprentie modiste': 'apprentie modiste',
#  'apprentier': 'apprenti',
#  'apprentis': 'apprenti',
#  'apprentisse': 'apprenti',
#  'arpentier': 'charpentier',
#  'atier': 'NSP',
#  'atiere': 'NSP',
#  'atif': 'NSP',
#  'aypographe': 'typographe',
#  'bauquier': 'banquier',
#  'belmont': nan,
#  'bem': 'NSP',
#  'ben': 'NSP',
#  'bens': 'NSP',
#  'berne': nan,
#  'beulanger': 'boulanger',
#  'bijoulier': 'bijoutier',
#  'bingere': 'lingere',
#  'blanchi ause': 'blanchisseuse',
#  'bonne': 'bonne',
#  'cafelier': 'cafetier',
#  'caiffeur': 'coiffeur',
#  'catelier': 'cafetier',
#  'chapellier': 'chapellier',
#  'charon': 'charron',
#  'charpent': 'charpentier',
#  'charrelier': 'charrelier',
#  'chirurgien': 'chirurgien',
#  'cimenteur': 'cimenteur',
#  'cinturier': 'ceinturier',
#  'clerc': 'clerc',
#  'cleve': 'eleve',
#  'clever caveug id': 'eleve|caveur|idem',
#  'coge': 'NSP',
#  'commissionnaire': 'commissionnaire',
#  'compagne': 'compagne',
#  'conne': 'bonne',
#  'conseiller': 'conseiller',
#  'cord': 'cordonnier ',
#  'cordonier': 'cordonnier',
#  'cordourier': 'cordonnier/couturier?',
#  'coucher': 'boucher',
#  'cousiniere': 'cuisiniere',
#  'couvrent': 'couvreur',
#  'cullieateur': 'cultivateur',
#  'cullisateur': 'cultivateur',
#  'culottier': 'cullotier',
#  'cultivateur': 'cultivateur',
#  'dam': 'NSP',
#  'de leur recepisse': 'NSP',
#  'de naisse': nan,
#  'del': 'NSP',
#  'delle de magasin': 'demoiselle de magasin',
#  'dem': 'idem',
#  'deux': 'NSP',
#  'dgne': 'domestique',
#  'dicelinaire': 'disciplinaire',
#  'diciolinaire': 'disciplinaire',
#  'diciphinaire id': 'disciplinaire',
#  'diephinaire': 'disciplinaire',
#  'dinier': 'jardinier',
#  'docteur': 'docteur',
#  'dom': 'domestique',
#  'dome': 'domestique',
#  'domel': 'domestique',
#  'domest': 'domestique',
#  'domesti': 'domestique',
#  'domestiq': 'domestique',
#  'domestiqne': 'domestique',
#  'domestique .': 'domestique',
#  'domestique cleves oapheline': 'domestique|eleve|orpheline',
#  'domestique domestique': 'domestique|domestique',
#  'domestique el regent': 'domestique|regent',
#  'domestique id': 'domestique|idem',
#  'domestique id id': 'domestique|idem|idem',
#  'domestique idem': 'domestique|idem',
#  'domestique ouvrier': 'domestique|ouvrier',
#  'domestique pensionnaire': 'domestique|pensionnaire',
#  'domestiques': 'domestique',
#  'domi': 'domestique',
#  'donnier': 'cordonnier',
#  'doue': 'domestique',
#  'dqe': 'domestique',
#  'dqu': 'NSP',
#  'dque dque': 'domestique|domestique',
#  'dque id': 'domestique|idem',
#  'due': 'domestique',
#  'dve': 'domestique',
#  'e id': 'NSP|idem',
#  'echaud': 'NSP',
#  'eleire': 'eleve',
#  'elene': 'eleve',
#  'elene aveug id': 'eleve|idem',
#  'eleve': 'eleve',
#  'eleve engent': 'eleve|regent',
#  'eleve regent': 'eleve|regent',
#  'eleve regente': 'eleve|regente',
#  'elieur': 'relieur',
#  'eline': 'NSP',
#  'emp': 'employe',
#  'emp . a la gare': 'employe a la gare',
#  'emp . au chateau': 'employe au chateau',
#  'emp . postal': 'employe postal',
#  'emp . so .': 'employe',
#  'emp de banque': 'employe de banque',
#  'emp j p': 'employe',
#  'emp j s': 'employe',
#  'emp so': 'employe',
#  'empl j s': 'employe',
#  'empl postal': 'employe postal',
#  'empley': 'employe',
#  'employe s': 'employe',
#  'employee': 'employee',
#  'employer interne': 'employe interne',
#  'en chambre': 'NSP',
#  'enf': 'enfant',
#  'enfant': 'enfant',
#  'enfant naturel': 'enfant naturel',
#  'enft illegit': 'enfant illegitime',
#  'enpension': 'en pension',
#  'epalinges': nan,
#  'epiciere': 'epiciere',
#  'et': nan,
#  'etier': 'rentier',
#  'etiere': 'rentiere',
#  'etudiant in': 'etudiant|idem',
#  'etudiante': 'etudiante',
#  'eypographe': 'typographe',
#  'fabriquent': 'fabricant',
#  'fait des menages': 'femme de ménage',
#  'felier': 'telier',
#  'fem de ch': 'femme de chambre',
#  'fem de chambre': 'femme de chambre',
#  'femme de ch': 'femme de chambre',
#  'fermiers': 'fermier',
#  'fernier': 'fermier',
#  'fetier': 'cafetier',
#  'fille de boutique': 'fille de boutique',
#  'fille de chambre': 'femme de chambre',
#  'fille de magasin': 'fille de magasin',
#  'filleuse': 'fileuse',
#  'fortier': 'fortier',
#  'gagne denier': 'gagne denier',
#  'gailleur': 'tailleur',
#  'garde de jour': 'garde de jour',
#  'garde feres': 'NSP',
#  'garde malade': 'garde malade',
#  'garde police': 'garde police',
#  'gardinier': 'jardinier',
#  'ge': 'NSP',
#  'gendanme': 'gendarme',
#  'gere': 'pere',
#  'gipier': 'gipier',
#  'gipseur': 'gipseur',
#  'gipsier': 'gipsier',
#  'gociant': 'negociant',
#  'gociante': 'negociante',
#  'gondarme': 'gendarme',
#  'got': 'NSP',
#  'gotiant': 'negociant',
#  'gouvernant pensionnaire': 'gouvernant|pensionnaire',
#  'gre': 'NSP',
#  'gte': 'NSP',
#  'guisier': 'guisier',
#  'gypseur': 'gypseur',
#  'gypsier': 'gypsier',
#  'henri': nan,
#  'henuisier': 'menuisier',
#  'hotelier': 'hotelier',
#  'ici': 'idem',
#  'id .': 'idem',
#  'id a': 'idem',
#  'id domestique': 'idem|domestique',
#  'id dque': 'idem|domestique',
#  'id i': 'idem|idem',
#  'id id': 'idem|idem',
#  'id id id': 'idem|idem|idem',
#  'id id id id': 'idem|idem|idem|idem',
#  'id ls': 'idem|idem',
#  'id n': 'idem',
#  'id ne aisse': 'idem|NA',
#  'id nee de naisse': 'idem|NA',
#  'id pensionnaire': 'idem|pensionnaire',
#  'ide': 'idem',
#  'idem .': 'idem',
#  'idem domestique': 'idem|domestique',
#  'idemidem': 'idem|idem',
#  'ideon': 'idem',
#  'idme': 'idem',
#  'idod': 'idem',
#  'idom': 'idem',
#  'idt': 'idem',
#  'ier': 'NSP',
#  'ilems': 'idem',
#  'ineurable': 'incurable',
#  'infirme': 'infirme',
#  'istre': 'NSP',
#  'jann': 'NSP',
#  'jaque': 'NSP',
#  'jardinier domestique': 'jardinier|domestique',
#  'jean': nan,
#  'jenny': 'NSP',
#  'jeun': 'NSP',
#  'jeurn': 'journalier',
#  'jone': 'NSP',
#  'journ': 'journalier',
#  'journailler': 'journalier',
#  'journaillere': 'journaliere',
#  'journaillier': 'journalier',
#  'journailliere': 'journaliere',
#  'journal': 'journalier',
#  'journalie': 'journalier',
#  'journalierer': 'journalier',
#  'journallier': 'journalier',
#  'journalliere': 'journalier',
#  'juge d appel': 'juge d appel',
#  'julier': 'NSP',
#  'kem': 'NSP',
#  'la vigneron': 'vigneron',
#  'labaure': 'laboureur',
#  'laber': 'laboureur',
#  'labour': 'laboureur',
#  'laboureur': 'laboureur',
#  'laboureure': 'laboureur',
#  'laboureuse': 'laboureuse',
#  'langer': 'boulanger',
#  'lans': 'NSP',
#  'laus': nan,
#  'lausanne': nan,
#  'lavandiere': 'lavandiere',
#  'lavendiere': 'lavandiere',
#  'lebaureur': 'laboureur',
#  'lecheur': 'pecheur',
#  'leffiveuse': 'lessiveuse',
#  'lege': 'NSP',
#  'len eogemont': 'NSP',
#  'lessineuse': 'lessiveuse',
#  'leur': 'NSP',
#  'leveregent idem': 'eleve|regent|idem',
#  'lie': 'NSP',
#  'lier': 'NSP',
#  'linger': 'linger',
#  'logeur': 'logeur',
#  'louis': nan,
#  'louise': nan,
#  'loye': 'employe',
#  'lque': 'domestique',
#  'ls vocation': 'sans vocation',
#  'lutry': nan,
#  'm boucher': 'maitre boucher',
#  'm cordonnier': 'maitre cordonnier',
#  'm de pension': 'maitre de pension',
#  'm jardinier': 'maitre jardinier',
#  'm tailleur': 'maitre tailleur',
#  'magon': 'macon',
#  'maitre': 'maitre',
#  'maitresse': 'maitresse',
#  'malade': 'malade',
#  'manoeuvre': 'manoeuvre',
#  'manouvrier': 'manouvrier',
#  'march': 'marchand',
#  'marchand de vin': 'marchand de vin',
#  'marchde': 'marchande',
#  'marche': 'marchand',
#  'marchs': 'marchand',
#  'marichal': 'marechal',
#  'maron': 'macon',
#  'masson': 'macon',
#  'me de pension': 'maitre de pension',
#  'menoeuvre': 'manoeuvre',
#  'menrier': 'NSP',
#  'menrinier': 'NSP',
#  'menritier': 'NSP',
#  'mension': 'NSP',
#  'mere': 'mere',
#  'merery': 'NSP',
#  'meron': 'NSP',
#  'minagere': 'menagere',
#  'monagere': 'menagere',
#  'monnier': 'meunier',
#  'moudon': nan,
#  'municapal': 'municipal',
#  'munier': 'meunier',
#  'nalade': 'malade',
#  'nalier': 'journalier',
#  'ne': 'NSP',
#  'nee de naisse': nan,
#  'negt': 'negociant',
#  'ni ds': 'NSP',
#  'niculteur': 'agriculteur',
#  'nier': 'NSP',
#  'no de': 'NSP',
#  'no de leur recepisse': 'NSP',
#  'no des': 'NSP',
#  'noge': 'NSP',
#  'nsesonaire pensionnaire': 'pensionnaire|pensionnaire',
#  'nuissier': 'huissier',
#  'ordonnier': 'cordonnier',
#  'orferre': 'orfevre',
#  'ounier': 'ouvrier',
#  'ournalier': 'journalier',
#  'ouv': 'ouvrier',
#  'ouv charpentier': 'ouvrier charpentier',
#  'ouv cordonnier': 'ouvrier cordonnier',
#  'ouv de ville': 'ouvrier de ville',
#  'ouv menuisier': 'ouvrier menuisier',
#  'ouv serrurier': 'ouvrier serrurier',
#  'ouvr macon d': 'ouvrier macon',
#  'ouvrier di': 'ouvrier',
#  'ouvrier loge': 'ouvrier',
#  'ouvrier menuisier': 'ouvrier menuisier',
#  'paint': 'peintre',
#  'pare': 'parent',
#  'parent': 'parent',
#  'paul': nan,
#  'paus': 'NSP',
#  'peint': 'peintre',
#  'pelier': 'chapelier',
#  'penre': 'peintre',
#  'pens': 'pensionnaire',
#  'pens .': 'pensionnaire',
#  'pens dque': 'pensionnaire|domestique',
#  'pensi': 'pensionnaire',
#  'pension': 'pensionnaire',
#  'pension re': 'pensionnaire',
#  'pensionaire': 'pensionnaire',
#  'pensionaire idem': 'pensionnaire|idem',
#  'pensionn': 'pensionnaire',
#  'pensionn .': 'pensionnaire',
#  'pensionna': 'pensionnaire',
#  'pensionnai': 'pensionnaire',
#  'pensionnaire .': 'pensionnaire',
#  'pensionnaire domestique': 'pensionnaire|domestique',
#  'pensionnaire dque': 'pensionnaire|domestique',
#  'pensionnaire id': 'pensionnaire',
#  'pensionnaire id id': 'pensionnaire|idem|idem',
#  'pensionnaire idem': 'pensionnaire|idem',
#  'pensionnaire pensionnaire': 'pensionnaire|pensionnaire',
#  'pensionnat': 'pensionnaire',
#  'pensionne': 'pensionnaire',
#  'pensionnre': 'pensionnaire',
#  'pensionr': 'pensionnaire',
#  'pensionre': 'pensionnaire',
#  'pensre': 'pensionnaire',
#  'pensre .': 'pensionnaire',
#  'pensre de': 'pensionnaire',
#  'pent': 'peintre',
#  'pentre': 'peintre',
#  'peus': 'NSP',
#  'pierre': nan,
#  'pilleuse': 'NSP',
#  'pins': 'NSP',
#  'poins': 'NSP',
#  'point': 'NSP',
#  'poirt': 'NSP',
#  'pomese': 'domestique',
#  'poprietaire': 'proprietaire',
#  'potier de terre': 'potier de terre',
#  'pouit': 'NSP',
#  'pourcoucher': 'boucher',
#  'pout': 'NSP',
#  'prafesseur': 'professeur',
#  'pre': 'NSP',
#  'prietaire': 'proprietaire',
#  'print': 'NSP',
#  'profession': 'sans profession',
#  'proprietair': 'proprietaire',
#  'psion': 'pensionnaire',
#  'pully': nan,
#  'rapes': 'NSP',
#  'reg': 'regent',
#  'regis': 'regent',
#  'regt': 'regent',
#  'reguste': 'droguiste',
#  'rent': 'rentier',
#  'rentiere .': 'rentier',
#  'rention': 'rentier',
#  'rentr': 'rentier',
#  'renuisier': 'menuisier',
#  'reulier': 'rentier',
#  'revendeuse': 'vendeuse',
#  nan: nan,
#  'rietaire': 'proprietaire',
#  'rintier': 'rentier',
#  'rnalier': 'journalier',
#  'rnaliere': 'journaliere',
#  'rnsimie': 'NSP',
#  'ront': 'NSP',
#  'rontr': 'NSP',
#  'roprietaire': 'proprietaire',
#  's profession': 'sans profession',
#  's vocation': 'sans vocation',
#  'sa fille': nan,
#  'sage femme': 'sage femme',
#  'sallieur': 'tailleur',
#  'sans': 'sans profession',
#  'sans profession': 'sans profession',
#  'sans voc': 'sans vocation',
#  'sans vocat': 'sans vocation',
#  'sansetta': 'NSP',
#  'sansette': 'NSP',
#  'saus': 'NSP',
#  'scieur': 'scieur',
#  'seiller': 'sellier',
#  'seillier': 'sellier',
#  'serrurrier': 'serrurrier',
#  'servante': 'servante',
#  'servante ouvrier': 'servante ouvrier',
#  'sifferand': 'tisserand',
#  'sineraud': 'NSP',
#  'sommeiller': 'sommeiller',
#  'sommeliere': 'sommeliere',
#  'son domestique': 'domestique',
#  'spocation': 'sans vocation',
#  'spvocation': 'sans vocation',
#  'st': 'NSP',
#  'st cordonnier': 'cordonnier',
#  'st profess': 'sans profession',
#  'st vocation': 'sans vocation',
#  'ste croix idhd': nan,
#  'svocation': 'sans vocation',
#  'syvocation': 'sans vocation',
#  'taboureur': 'taboureur',
#  'tailleur d habits': 'tailleur d habits',
#  'tailleur de pierres': 'tailleur de pierres',
#  'tailleure': 'tailleur',
#  'taillieur': 'taillieur',
#  'taillieus': 'taillieuse',
#  'taillieuse': 'taillieuse',
#  'tanneux': 'tanneur',
#  'tendeur de vin': 'vendeur de vin',
#  'terrassier': 'terrassier',
#  'tient ecole': 'tient une ecole',
#  'tiere': 'NSP',
#  'tilleur': 'taillieur',
#  'tisseraud': 'tisserand',
#  'toujours': 'NSP',
#  'typographe': 'typographe',
#  'une': 'NSP',
#  'valet de chambre': 'valet de chambre',
#  'valteur': 'NSP',
#  'vandeur de vin': 'vendeur de vin',
#  'vend vin': 'vendeur de vin',
#  'vendoin': 'vendeur de vin',
#  'venre': 'NSP',
#  'veudeur de vin': 'vendeur de vin',
#  'veuve': 'veuve',
#  'vigneron d': 'vigneron',
#  'vigneronne': 'vigneronne',
#  'vintier': 'pintier',
#  'vit de ses rentes': 'rentier',
#  'vit de sesrenter': 'rentier',
#  'vit de sesrentes': 'rentier',
#  'vocatier': 'NSP',
#  'vocation': 'sans vocation',
#  'voiturier .': 'voiturier',
#  'volontaire': 'volontaire',
#  'vve de chambre': 'valet de chambre',
#  'murier': 'armurier',
#  'griculteur': 'agriculteur',
#  'renlier': 'rentier'}

# %%
len(top_terms)
# Out:
# 532

# %%
import numpy as np


correct_terms = (set(man_corr["corrected"].str.split("|").explode()) - {"NA", "NSP", "idem", np.nan}).union(top_terms.intersection(jobs_1855))
correct_terms = sorted(list(correct_terms))

# %%
correct_terms
# Out:
# ['agent',
#  'agent de police',
#  'agriculteur',
#  'aide',
#  'apprenti',
#  'apprenti negociant',
#  'apprentie',
#  'apprentie couturiere',
#  'apprentie modiste',
#  'apprentie tailleuse',
#  'architecte',
#  'armurier',
#  'arpenteur',
#  'aubergiste',
#  'avocat',
#  'banquier',
#  'batelier',
#  'bijoutier',
#  'blanchisseuse',
#  'bonne',
#  'bottier',
#  'boucher',
#  'boulanger',
#  'bucheron',
#  'cafetier',
#  'carrier',
#  'caveur',
#  'ceinturier',
#  'chapelier',
#  'chapellier',
#  'charcutier',
#  'charpentier',
#  'charrelier',
#  'charretier',
#  'charron',
#  'chaudronnier',
#  'chauffeur',
#  'chirurgien',
#  'cimenteur',
#  'clerc',
#  'cocher',
#  'coiffeur',
#  'commis',
#  'commissionnaire',
#  'compagne',
#  'compositeur',
#  'comptable',
#  'concierge',
#  'conducteur',
#  'confiseur',
#  'conseiller',
#  'cordonnier',
#  'cordonnier ',
#  'cordonnier/couturier?',
#  'corroyeur',
#  'courtier',
#  'couturiere',
#  'couvreur',
#  'cuisinier',
#  'cuisiniere',
#  'cullotier',
#  'cultivateur',
#  'demoiselle de magasin',
#  'directeur',
#  'disciplinaire',
#  'docteur',
#  'domestique',
#  'dque',
#  'droguiste',
#  'ebeniste',
#  'ecrivain',
#  'eleve',
#  'employe',
#  'employe a la gare',
#  'employe au chateau',
#  'employe de banque',
#  'employe interne',
#  'employe postal',
#  'employee',
#  'en pension',
#  'enfant',
#  'enfant illegitime',
#  'enfant naturel',
#  'entrepreneur',
#  'epicier',
#  'epiciere',
#  'etudiant',
#  'etudiante',
#  'fabricant',
#  'facteur',
#  'femme de chambre',
#  'femme de ménage',
#  'ferblantier',
#  'fermier',
#  'fileur',
#  'fileuse',
#  'fille de boutique',
#  'fille de magasin',
#  'fondeur',
#  'fontenier',
#  'fortier',
#  'fruitier',
#  'gagne denier',
#  'gantier',
#  'garcon de cafe',
#  'garde de jour',
#  'garde malade',
#  'garde police',
#  'gendarme',
#  'gipier',
#  'gipseur',
#  'gipsier',
#  'gouvernant',
#  'guisier',
#  'gypseur',
#  'gypsier',
#  'horloger',
#  'hotelier',
#  'huissier',
#  'id',
#  'imprimeur',
#  'incurable',
#  'infirme',
#  'infirmier',
#  'ingenieur',
#  'inspecteur',
#  'institut',
#  'instituteur',
#  'institutrice',
#  'jardinier',
#  'journalier',
#  'journaliere',
#  'juge',
#  'juge d appel',
#  'laboureur',
#  'laboureuse',
#  'laitier',
#  'lavandiere',
#  'lessiveuse',
#  'libraire',
#  'linger',
#  'lingere',
#  'locataire',
#  'loge',
#  'logeur',
#  'logeuse',
#  'macon',
#  'maitre',
#  'maitre boucher',
#  'maitre cordonnier',
#  'maitre de pension',
#  'maitre jardinier',
#  'maitre tailleur',
#  'maitresse',
#  'malade',
#  'manoeuvre',
#  'manouvrier',
#  'marbrier',
#  'marchand',
#  'marchand de vin',
#  'marchande',
#  'marechal',
#  'mecanicien',
#  'medecin',
#  'menagere',
#  'menuisier',
#  'mere',
#  'meunier',
#  'mineur',
#  'ministre',
#  'modiste',
#  'municipal',
#  'musicien',
#  'negociant',
#  'negociante',
#  'notaire',
#  'orfevre',
#  'orpheline',
#  'ouvrier',
#  'ouvrier charpentier',
#  'ouvrier cordonnier',
#  'ouvrier de ville',
#  'ouvrier macon',
#  'ouvrier menuisier',
#  'ouvrier serrurier',
#  'ouvriere',
#  'parent',
#  'pasteur',
#  'patissier',
#  'pecheur',
#  'peintre',
#  'pensionnair',
#  'pensionnaire',
#  'pensionnaires',
#  'pere',
#  'perruquier',
#  'pharmacien',
#  'pintier',
#  'pionnier',
#  'platrier',
#  'portier',
#  'potier de terre',
#  'professeur',
#  'proprietaire',
#  'regent',
#  'regente',
#  'relieur',
#  'rentier',
#  'rentiere',
#  'repasseuse',
#  'sa mere',
#  'sage femme',
#  'sans profession',
#  'sans vocation',
#  'scieur',
#  'secretaire',
#  'sellier',
#  'serrurier',
#  'serrurrier',
#  'servante',
#  'servante ouvrier',
#  'socquier',
#  'sommeiller',
#  'sommelier',
#  'sommeliere',
#  'taboureur',
#  'tailleur',
#  'tailleur d habits',
#  'tailleur de pierre',
#  'tailleur de pierres',
#  'tailleuse',
#  'taillieur',
#  'taillieuse',
#  'tanneur',
#  'tapissier',
#  'teinturier',
#  'telegraphiste',
#  'telier',
#  'terrassier',
#  'tient pension',
#  'tient une ecole',
#  'tier',
#  'tisserand',
#  'tonnelier',
#  'tourneur',
#  'traiteur',
#  'typographe',
#  'valet de chambre',
#  'vannier',
#  'vendeur de vin',
#  'vendeuse',
#  'veuve',
#  'vigneron',
#  'vigneronne',
#  'vitrier',
#  'voiturier',
#  'volontaire']

# %%
df = pd.DataFrame(correct_terms)

# %%
df.to_csv("eiarsndkfhj.csv")

# %%
cw = csv.writer(open("correct_terms.csv",'w'))
for i in correct_terms:
    cw.writerows(i)

# %%
with open('correct_terms.csv', 'w') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
    for i in correct_terms:
        write.writerow(i)
